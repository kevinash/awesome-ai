# %% [markdown]
# # Shading

# %%
from PIL import Image
import matplotlib.pyplot as plt
import torch
import cv2
# %matplotlib inline

import utils.shading.predict_helper as shader

# %%
shader.predict()
# Out:
# Running inference for ./media/sketches\42.png ...
# Running inference for ./media/sketches\author.png ...
# Running inference for ./media/sketches\cyborg_girl.png ...
# Running inference for ./media/sketches\girl_with_robotic_arm.png ...
# Running inference for ./media/sketches\scientist.png ...
# Running inference for ./media/sketches\surfer.png ...
# Running inference for ./media/sketches\weightlifter.png ...

# %%
img = cv2.imread('./.output/42.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img); 
plt.show()

# %% [markdown]
# References:
#
# Applying shading to sketches is Paper (arxiv.org)
# qyzdao/ShadeSketch: Implementation of "Learning to Shadow Hand-drawn Sketches" CVPR 2020 (Oral) https://github.com/qyzdao/ShadeSketch
#
# https://bvraghav.com/shad3s/
