# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "124M"
file_name = "shakespeare.txt"

# %%
if not os.path.isdir(os.path.join("models", model_name)):
    print(f"Downloading {model_name} model...")
    gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Downloading 124M model...
# Fetching checkpoint: 1.05Mit [00:00, 524Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 6.77Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 249Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:21, 22.9Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 262Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 13.8Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 10.8Mit/s]

# %%
if not os.path.isfile(file_name):
    url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
    data = requests.get(url)

    with open(file_name, 'w') as f:
        f.write(data.text)

# %%
import tensorflow as tf
tf.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=1000,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=200,
              save_every=500
              )

gpt2.generate(sess)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[{{node model/wpe/Initializer/random_normal/stddev}}]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-9-32a0e4150b39> in <module>()
#      10               print_every=10,
#      11               sample_every=200,
# ---> 12               save_every=500
#      13               )
#      14
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     241         var_list=all_vars,
#     242         max_to_keep=max_checkpoints)
# --> 243     sess.run(tf.compat.v1.global_variables_initializer())
#     244
#     245     if restore_from == 'latest':
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[node model/wpe/Initializer/random_normal/stddev (defined at C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'model/wpe/Initializer/random_normal/stddev':
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-9-32a0e4150b39>", line 12, in <module>
#     save_every=500
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\gpt_2.py", line 198, in finetune
#     output = model.model(hparams=hparams, X=context, gpus=gpus)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\model.py", line 183, in model
#     initializer=tf.compat.v1.random_normal_initializer(stddev=0.01))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 1500, in get_variable
#     aggregation=aggregation)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 1243, in get_variable
#     aggregation=aggregation)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 567, in get_variable
#     aggregation=aggregation)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 519, in _true_getter
#     aggregation=aggregation)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 933, in _get_single_variable
#     aggregation=aggregation)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 258, in __call__
#     return cls._variable_v1_call(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 219, in _variable_v1_call
#     shape=shape)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 197, in <lambda>
#     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 2519, in default_variable_creator
#     shape=shape)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 262, in __call__
#     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 1688, in __init__
#     shape=shape)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variables.py", line 1818, in _init_from_args
#     initial_value(), name="initial_value", dtype=dtype)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\variable_scope.py", line 905, in <lambda>
#     partition_info=partition_info)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\init_ops.py", line 323, in __call__
#     shape, self.mean, self.stddev, dtype, seed=self.seed)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\random_ops.py", line 71, in random_normal
#     stddev_tensor = ops.convert_to_tensor(stddev, dtype=dtype, name="stddev")
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1184, in convert_to_tensor
#     return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1242, in convert_to_tensor_v2
#     as_ref=False)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1297, in internal_convert_to_tensor
#     ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\tensor_conversion_registry.py", line 52, in _default_conversion_function
#     return constant_op.constant(value, dtype, name=name)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\constant_op.py", line 227, in constant
#     allow_broadcast=True)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\constant_op.py", line 271, in _constant_impl
#     name=name).outputs[0]
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
import gpt_2_simple as gpt2

sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess)

gpt2.generate(sess)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Loading checkpoint None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-ad9eea178ac9> in <module>()
#       2
#       3 sess = gpt2.start_tf_sess()
# ----> 4 gpt2.load_gpt2(sess)
#       5
#       6 gpt2.generate(sess)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\gpt_2.py in load_gpt2(sess, run_name, checkpoint_dir, model_name, model_dir, multi_gpu)
#     397     else:
#     398         print('Loading checkpoint', ckpt)
# --> 399     saver.restore(sess, ckpt)
#     400
#     401
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\training\saver.py in restore(self, sess, save_path)
#    1275       return
#    1276     if save_path is None:
# -> 1277       raise ValueError("Can't load save_path when it is None.")
#    1278
#    1279     checkpoint_prefix = compat.as_text(save_path)
#
# ValueError: Can't load save_path when it is None.

# %%
single_text = gpt2.generate(sess, return_as_list=True)[0]
print(single_text)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[{{node sample_sequence_1/model/h0/ln_1/add/y}}]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-10-83bed87065e5> in <module>()
# ----> 1 single_text = gpt2.generate(sess, return_as_list=True)[0]
#       2 print(single_text)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\gpt_2.py in generate(sess, run_name, checkpoint_dir, model_name, model_dir, sample_dir, return_as_list, truncate, destination_path, sample_delim, prefix, seed, nsamples, batch_size, length, temperature, top_k, top_p, include_prefix)
#     466     while generated < nsamples:
#     467         if not prefix:
# --> 468             out = sess.run(output)
#     469         else:
#     470             out = sess.run(output, feed_dict={
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor of shape [] and type float
# 	 [[node sample_sequence_1/model/h0/ln_1/add/y (defined at C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'sample_sequence_1/model/h0/ln_1/add/y':
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\kernelbase.py", line 541, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-83bed87065e5>", line 1, in <module>
#     single_text = gpt2.generate(sess, return_as_list=True)[0]
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\gpt_2.py", line 459, in generate
#     temperature=temperature, top_k=top_k, top_p=top_p
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\sample.py", line 67, in sample_sequence
#     context_output = step(hparams, context[:, :-1])
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\sample.py", line 52, in step
#     past=past, reuse=tf.compat.v1.AUTO_REUSE)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\model.py", line 197, in model
#     h, present = block(h, 'h%d' % layer, past=past, hparams=hparams)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\model.py", line 156, in block
#     a, present = attn(norm(x, 'ln_1'), 'attn', nx, past=past, hparams=hparams)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\gpt_2_simple\src\model.py", line 66, in norm
#     x = (x - u) * tf.math.rsqrt(s + epsilon)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\ops\math_ops.py", line 903, in binary_op_wrapper
#     y, dtype_hint=x.dtype.base_dtype, name="y")
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1242, in convert_to_tensor_v2
#     as_ref=False)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1285, in internal_convert_to_tensor
#     value, dtype=preferred_dtype, name=name, as_ref=as_ref)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\tensor_conversion_registry.py", line 52, in _default_conversion_function
#     return constant_op.constant(value, dtype, name=name)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\constant_op.py", line 227, in constant
#     allow_broadcast=True)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\constant_op.py", line 271, in _constant_impl
#     name=name).outputs[0]
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\envs\tf11\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
